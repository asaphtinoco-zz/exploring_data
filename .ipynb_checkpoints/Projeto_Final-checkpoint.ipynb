# %% [markdown]
# # Pump it up: Data Mining and the water table

# %% [markdown]
# Hello y'all, today I will be running my solution for a water's pump predictive maintenance. This dataset was firstly difused by [drivendata.org](drivendata.org) in order to propose a cheaper solution for Tanzania's water distribution.
#
# I'll do this in five parts as listed below:
#
# * Gathering and Exploring Data
# * Processing data
# * Researching a model that fits
# * Training and Testing
# * Evaluation

# %% [markdown]
# ### 1. Gathering and Exploring Data
# Here, the first thing is see what data looks like and get the next further steps.

# %%
import pandas as pd
df_values = pd.read_csv (r'G:\Meu Drive\UFRJ Disciplinas\Projeto Final\pump-it-up-data-mining-the-water-table\Pump_it_Up_Data_Mining_the_Water_Table_-_Training_set_values.csv')
df_labels = pd.read_csv (r'G:\Meu Drive\UFRJ Disciplinas\Projeto Final\pump-it-up-data-mining-the-water-table\Pump_it_Up_Data_Mining_the_Water_Table_-_Training_set_labels.csv')
df = pd.merge (df_values,df_labels, how = 'inner')

# exploring data 
df.head(10)
# Out:
#       id  amount_tsh date_recorded               funder  gps_height  \
# 0  69572      6000.0    2011-03-14                Roman        1390
# 1   8776         0.0    2013-03-06              Grumeti        1399
# 2  34310        25.0    2013-02-25         Lottery Club         686
# 3  67743         0.0    2013-01-28               Unicef         263
# 4  19728         0.0    2011-07-13          Action In A           0
# 5   9944        20.0    2011-03-13  Mkinga Distric Coun           0
# 6  19816         0.0    2012-10-01                 Dwsp           0
# 7  54551         0.0    2012-10-09                Rwssp           0
# 8  53934         0.0    2012-11-03             Wateraid           0
# 9  46144         0.0    2011-08-03          Isingiro Ho           0
#
#       installer  longitude   latitude              wpt_name  num_private  ...  \
# 0         Roman  34.938093  -9.856322                  none            0  ...
# 1       GRUMETI  34.698766  -2.147466              Zahanati            0  ...
# 2  World vision  37.460664  -3.821329           Kwa Mahundi            0  ...
# 3        UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...
# 4       Artisan  31.130847  -1.825359               Shuleni            0  ...
# 5           DWE  39.172796  -4.765587                Tajiri            0  ...
# 6          DWSP  33.362410  -3.766365            Kwa Ngomho            0  ...
# 7           DWE  32.620617  -4.226198          Tushirikiane            0  ...
# 8     Water Aid  32.711100  -5.146712     Kwa Ramadhan Musa            0  ...
# 9       Artisan  30.626991  -1.257051               Kwapeto            0  ...
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
# 3          soft          good           dry             dry
# 4          soft          good      seasonal        seasonal
# 5         salty         salty        enough          enough
# 6          soft          good        enough          enough
# 7         milky         milky        enough          enough
# 8         salty         salty      seasonal        seasonal
# 9          soft          good        enough          enough
#
#                  source           source_type source_class  \
# 0                spring                spring  groundwater
# 1  rainwater harvesting  rainwater harvesting      surface
# 2                   dam                   dam      surface
# 3           machine dbh              borehole  groundwater
# 4  rainwater harvesting  rainwater harvesting      surface
# 5                 other                 other      unknown
# 6           machine dbh              borehole  groundwater
# 7          shallow well          shallow well  groundwater
# 8           machine dbh              borehole  groundwater
# 9          shallow well          shallow well  groundwater
#
#                waterpoint_type waterpoint_type_group    status_group
# 0           communal standpipe    communal standpipe      functional
# 1           communal standpipe    communal standpipe      functional
# 2  communal standpipe multiple    communal standpipe      functional
# 3  communal standpipe multiple    communal standpipe  non functional
# 4           communal standpipe    communal standpipe      functional
# 5  communal standpipe multiple    communal standpipe      functional
# 6                    hand pump             hand pump  non functional
# 7                    hand pump             hand pump  non functional
# 8                    hand pump             hand pump  non functional
# 9                    hand pump             hand pump      functional
#
# [10 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59400 entries, 0 to 59399
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59400 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59029 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
#  14  district_code          59400 non-null  int64
#  15  lga                    59400 non-null  object
#  16  ward                   59400 non-null  object
#  17  population             59400 non-null  int64
#  18  public_meeting         56066 non-null  object
#  19  recorded_by            59400 non-null  object
#  20  scheme_management      55523 non-null  object
#  21  scheme_name            31234 non-null  object
#  22  permit                 56344 non-null  object
#  23  construction_year      59400 non-null  int64
#  24  extraction_type        59400 non-null  object
#  25  extraction_type_group  59400 non-null  object
#  26  extraction_type_class  59400 non-null  object
#  27  management             59400 non-null  object
#  28  management_group       59400 non-null  object
#  29  payment                59400 non-null  object
#  30  payment_type           59400 non-null  object
#  31  water_quality          59400 non-null  object
#  32  quality_group          59400 non-null  object
#  33  quantity               59400 non-null  object
#  34  quantity_group         59400 non-null  object
#  35  source                 59400 non-null  object
#  36  source_type            59400 non-null  object
#  37  source_class           59400 non-null  object
#  38  waterpoint_type        59400 non-null  object
#  39  waterpoint_type_group  59400 non-null  object
#  40  status_group           59400 non-null  object
# dtypes: float64(3), int64(7), object(31)
# memory usage: 19.0+ MB

# %% [markdown]
# * As we can see, most of our variables are categorical. I've chosen a subset of data to explore and test its influences on the variable that we want predict. The variables was chosen based in some criterias

# %%
df_eda = df[['id','permit','date_recorded','amount_tsh','gps_height','longitude','latitude','wpt_name','region','population','public_meeting','construction_year','payment','source','waterpoint_type','status_group','quantity','basin']]
df_eda.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  59400.000000   59400.000000  59400.000000  59400.000000  5.940000e+04
# mean   37115.131768     317.650385    668.297239     34.077427 -5.706033e+00
# std    21453.128371    2997.574558    693.116350      6.567432  2.946019e+00
# min        0.000000       0.000000    -90.000000      0.000000 -1.164944e+01
# 25%    18519.750000       0.000000      0.000000     33.090347 -8.540621e+00
# 50%    37061.500000       0.000000    369.000000     34.908743 -5.021597e+00
# 75%    55656.500000      20.000000   1319.250000     37.178387 -3.326156e+00
# max    74247.000000  350000.000000   2770.000000     40.345193 -2.000000e-08
#
#          population  construction_year
# count  59400.000000       59400.000000
# mean     179.909983        1300.652475
# std      471.482176         951.620547
# min        0.000000           0.000000
# 25%        0.000000           0.000000
# 50%       25.000000        1986.000000
# 75%      215.000000        2004.000000
# max    30500.000000        2013.000000

# %% [markdown]
# #### We'll be exploring our numerical data and then run our EDA
#
# As we can see below, there are many missing *construction year* value. Then further we'll handle this values in order to going foward with our analysis

# %%
import matplotlib.pyplot as plt
graph_1 = df_eda['construction_year'].hist()
plt.title('CONSTRUCTION YEAR')
plt.show(graph_1)

# %%
test = df_eda[['population','permit']]
test_groupby = test.groupby('permit')
test_groupby.sum().plot.bar()
plt.title('PERMISSION TO ACCESS DATA POINT')
# Out:
# Text(0.5, 1.0, 'PERMISSION TO ACCESS DATA POINT')

# %%
graph_1 = df_eda['gps_height'].hist()
plt.title('GPS HEIGHT')
plt.show(graph_1)

# %%
graph_1 = df_eda['amount_tsh'].hist()
plt.title('STATIC HEAD')
plt.show(graph_1)

# %%
import matplotlib.pyplot as plt
import matplotlib

df_eda_year = df_eda[df_eda['construction_year'] != 0][['construction_year','status_group']]
ct = pd.crosstab(df_eda_year.construction_year, df_eda_year.status_group,normalize='index')

ct.plot.bar(stacked=True,figsize=(20,10))
plt.legend(title='status_group')
plt.ylabel('Percentage of Pumps')
plt.xlabel('Construction Year')
plt.show()

# %%
df_eda_pm = df_eda[df_eda['construction_year'] != 0][['public_meeting','status_group']]
ct = pd.crosstab(df_eda_pm.public_meeting, df_eda_pm.status_group,normalize='index')
ct.plot.bar(stacked=True,figsize=(10,5))
plt.legend(title='status_group')
plt.ylabel('Percentage of Pumps')
plt.xlabel('Public Meeting')
plt.show()

# %%
df_eda_pay = df_eda[df_eda['construction_year'] != 0][['payment','status_group']]
ct = pd.crosstab(df_eda_pay.payment, df_eda_pay.status_group,normalize='index')
ct.plot.bar(stacked=True,figsize=(10,5))
plt.title('STATUS PAYMENT')
plt.ylabel('Percentage of Pumps')
plt.xlabel('Public Meeting')
plt.show()

# %%
df_eda_pay = df_eda[df_eda['construction_year'] != 0][['source','status_group']]
ct = pd.crosstab(df_eda_pay.source, df_eda_pay.status_group,normalize='index')
ct.plot.bar(stacked=True,figsize=(10,5))
plt.legend(title='status_group')
plt.ylabel('Percentage of Pumps')
plt.xlabel('Public Meeting')
plt.show()

# %%
df_eda_pay = df_eda[df_eda['construction_year'] != 0][['waterpoint_type','status_group']]
ct = pd.crosstab(df_eda_pay.waterpoint_type, df_eda_pay.status_group,normalize='index')
ct.plot.bar(stacked=True,figsize=(12,10))
plt.legend(title='status_group')
plt.ylabel('Percentage of Pumps')
plt.xlabel('waterpoint_type')
plt.show()

# %%
df_eda_pay = df_eda[df_eda['construction_year'] != 0][['region','status_group']]
ct = pd.crosstab(df_eda_pay.region, df_eda_pay.status_group,normalize='index')
ct.plot.bar(stacked=True,figsize=(12,10))
plt.legend(title='status_group')
plt.ylabel('Percentage of Pumps')
plt.xlabel('region')
plt.show()

# %%
df_eda_pay = df_eda[df_eda['construction_year'] != 0][['quantity','status_group']]
ct = pd.crosstab(df_eda_pay.quantity, df_eda_pay.status_group,normalize='index')
ct.plot.bar(stacked=True,figsize=(12,10))
plt.legend(title='status_group')
plt.ylabel('Percentage of Pumps')
plt.xlabel('quantity')
plt.show()

# %%
df_eda_pay = df_eda[df_eda['construction_year'] != 0][['gps_height','status_group']]
df_eda_pay['gps_height_cut'] = pd.cut(df_eda_pay['gps_height'],5)
ct = pd.crosstab(df_eda_pay.gps_height_cut, df_eda_pay.status_group,normalize='index')
ct.plot.bar(stacked=True,figsize=(12,10))
plt.legend(title='status_group')
plt.ylabel('Percentage of Pumps')
plt.xlabel('quantity')
plt.show()

# %% [markdown]
# ### Another important observations is the *static head*
#
# * This variable mean the amount of energy needed by the pump to move a amount os mass (of water).
# * We can clearly see that pumps with lower heads are likely to fail

# %%
import numpy as np 

df_head = df_eda[df_eda['construction_year']!= 0]
df_head['cut_head'] = pd.cut(df_eda['amount_tsh'],bins = [-np.inf,0,1,2,3,4,5,10,15,20,25, np.inf])
df_head['cut_head'].value_counts()
ct = pd.crosstab(df_head['cut_head'],df_head['status_group'],normalize = 'index')
ct.plot.bar(stacked=True,figsize=(12,10))
# Out:
# C:\Users\Asaph Tinoco\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# * We have almost 30% of our dataset with null values for year, as we're handle with large dataset, i'll be deleting these rows
# * I'll be choosing region data instead of longitude and latitude data, but I'll keep gps height.

# %% [markdown]
# ### 2. Preprocessing Data
# #### 2.1 Inputation
# * As seen before, about 30% of the variable *construction year* is missing, then I've chosen to drop all rows concerned, given that we have a large data set...

# %% [markdown]
# #### 2.2 Binning
# * For those who pay, instead of split in many classifications as it is, I'll be replacing by only for who pay, not pay and unknow
# * For tsh_amount (the static head) I will be classifying into 3 categories (low,mid,high)
# * Instead of *construction year* I'll be replacing by year of use: That will be de difference bewtween *construction year* and *date recorded*

# %%
#Filtering Year
df_eda_bin = df[df['construction_year'] != 0][['id','permit','date_recorded','amount_tsh','gps_height','wpt_name','region','population','public_meeting','construction_year','payment','source','waterpoint_type','status_group','quantity','latitude','longitude','basin']]
df_eda_bin = df_eda_bin[df_eda_bin['construction_year']!=0]

# Payment
df_eda_bin['payment'] = df_eda_bin['payment'].str.replace('pay annually','pay')
df_eda_bin['payment'] = df_eda_bin['payment'].str.replace('pay per bucket','pay')
df_eda_bin['payment'] = df_eda_bin['payment'].str.replace('pay annually','pay')
df_eda_bin['payment'] = df_eda_bin['payment'].str.replace('pay monthly','pay')
df_eda_bin['payment'] = df_eda_bin['payment'].str.replace('pay when scheme fails','pay')


#Static Head
df_eda_bin['amount_tsh_cut'] = pd.cut(df_eda_bin['amount_tsh'], bins = [-np.inf,1,15, np.inf], labels = ['Low', 'Mid', 'High'])


# Year of use
pd.to_datetime(df_eda_bin['date_recorded'])
df_eda_bin['recorded_date_year'] = pd.DatetimeIndex(df_eda_bin['date_recorded']).year
df_eda_bin['usage_period'] =  df_eda_bin['recorded_date_year'] - df_eda_bin['construction_year']
df_eda_bin = df_eda_bin[df_eda_bin['usage_period'] >= 0]


# Status Group 
df_eda_bin['status_group'] = df_eda_bin['status_group'].str.replace('functional needs repair','needs repair')
df_eda_bin['status_group'] = df_eda_bin['status_group'].str.replace('non functional','needs repair')

#
df_eda_bin['gps_height_cut'] = pd.cut(df_eda_bin['gps_height'], 5, labels = ['Low', 'Mid-Low','Mid','Mid-High', 'High'])

df_eda_bin.head()
df_eda_bin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38682 entries, 0 to 59399
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  38682 non-null  int64
#  1   permit              36755 non-null  object
#  2   date_recorded       38682 non-null  object
#  3   amount_tsh          38682 non-null  float64
#  4   gps_height          38682 non-null  int64
#  5   wpt_name            38682 non-null  object
#  6   region              38682 non-null  object
#  7   population          38682 non-null  int64
#  8   public_meeting      36377 non-null  object
#  9   construction_year   38682 non-null  int64
#  10  payment             38682 non-null  object
#  11  source              38682 non-null  object
#  12  waterpoint_type     38682 non-null  object
#  13  status_group        38682 non-null  object
#  14  quantity            38682 non-null  object
#  15  latitude            38682 non-null  float64
#  16  longitude           38682 non-null  float64
#  17  basin               38682 non-null  object
#  18  amount_tsh_cut      38682 non-null  category
#  19  recorded_date_year  38682 non-null  int64
#  20  usage_period        38682 non-null  int64
#  21  gps_height_cut      38682 non-null  category
# dtypes: category(2), float64(3), int64(6), object(11)
# memory usage: 6.3+ MB

# %%
ct = pd.crosstab(df_eda_bin.usage_period, df_eda_bin.status_group,normalize='index')
ct.plot.bar(stacked=True,figsize=(20,10))
plt.legend(title='status_group')
plt.ylabel('Percentage of Pumps')
plt.xlabel('Construction Year')
plt.show()

# %%
#### 2.3 One-Hot Encoding
df_n_dummies = df_eda_bin[['usage_period','population','status_group']]
df_dummies = df_eda_bin[['waterpoint_type','region','payment','source','quantity','amount_tsh_cut','basin','gps_height_cut']]
df_dummies = pd.get_dummies(df_dummies, drop_first = True)
df_train_test = pd.concat([df_dummies, df_n_dummies], axis = 1)
df_train_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38682 entries, 0 to 59399
# Data columns (total 55 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   waterpoint_type_communal standpipe           38682 non-null  uint8
#  1   waterpoint_type_communal standpipe multiple  38682 non-null  uint8
#  2   waterpoint_type_dam                          38682 non-null  uint8
#  3   waterpoint_type_hand pump                    38682 non-null  uint8
#  4   waterpoint_type_improved spring              38682 non-null  uint8
#  5   waterpoint_type_other                        38682 non-null  uint8
#  6   region_Dar es Salaam                         38682 non-null  uint8
#  7   region_Iringa                                38682 non-null  uint8
#  8   region_Kigoma                                38682 non-null  uint8
#  9   region_Kilimanjaro                           38682 non-null  uint8
#  10  region_Lindi                                 38682 non-null  uint8
#  11  region_Manyara                               38682 non-null  uint8
#  12  region_Mara                                  38682 non-null  uint8
#  13  region_Morogoro                              38682 non-null  uint8
#  14  region_Mtwara                                38682 non-null  uint8
#  15  region_Mwanza                                38682 non-null  uint8
#  16  region_Pwani                                 38682 non-null  uint8
#  17  region_Rukwa                                 38682 non-null  uint8
#  18  region_Ruvuma                                38682 non-null  uint8
#  19  region_Shinyanga                             38682 non-null  uint8
#  20  region_Singida                               38682 non-null  uint8
#  21  region_Tanga                                 38682 non-null  uint8
#  22  payment_other                                38682 non-null  uint8
#  23  payment_pay                                  38682 non-null  uint8
#  24  payment_unknown                              38682 non-null  uint8
#  25  source_hand dtw                              38682 non-null  uint8
#  26  source_lake                                  38682 non-null  uint8
#  27  source_machine dbh                           38682 non-null  uint8
#  28  source_other                                 38682 non-null  uint8
#  29  source_rainwater harvesting                  38682 non-null  uint8
#  30  source_river                                 38682 non-null  uint8
#  31  source_shallow well                          38682 non-null  uint8
#  32  source_spring                                38682 non-null  uint8
#  33  source_unknown                               38682 non-null  uint8
#  34  quantity_enough                              38682 non-null  uint8
#  35  quantity_insufficient                        38682 non-null  uint8
#  36  quantity_seasonal                            38682 non-null  uint8
#  37  quantity_unknown                             38682 non-null  uint8
#  38  amount_tsh_cut_Mid                           38682 non-null  uint8
#  39  amount_tsh_cut_High                          38682 non-null  uint8
#  40  basin_Lake Nyasa                             38682 non-null  uint8
#  41  basin_Lake Rukwa                             38682 non-null  uint8
#  42  basin_Lake Tanganyika                        38682 non-null  uint8
#  43  basin_Lake Victoria                          38682 non-null  uint8
#  44  basin_Pangani                                38682 non-null  uint8
#  45  basin_Rufiji                                 38682 non-null  uint8
#  46  basin_Ruvuma / Southern Coast                38682 non-null  uint8
#  47  basin_Wami / Ruvu                            38682 non-null  uint8
#  48  gps_height_cut_Mid-Low                       38682 non-null  uint8
#  49  gps_height_cut_Mid                           38682 non-null  uint8
#  50  gps_height_cut_Mid-High                      38682 non-null  uint8
#  51  gps_height_cut_High                          38682 non-null  uint8
#  52  usage_period                                 38682 non-null  int64
#  53  population                                   38682 non-null  int64
#  54  status_group                                 38682 non-null  object
# dtypes: int64(2), object(1), uint8(52)
# memory usage: 3.1+ MB

# %%
from sklearn.model_selection import train_test_split
y = df_train_test.iloc[:,-1]
X = df_train_test.drop(['status_group'], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 42)

y_test.value_counts(1)
# Out:
# functional      0.568979
# needs repair    0.431021
# Name: status_group, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

logreg.fit(X_train,y_train)
y_pred = logreg.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# C:\Users\Asaph Tinoco\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#               precision    recall  f1-score   support
#
#   functional       0.75      0.84      0.79      6603
# needs repair       0.75      0.62      0.68      5002
#
#     accuracy                           0.75     11605
#    macro avg       0.75      0.73      0.73     11605
# weighted avg       0.75      0.75      0.74     11605

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

dt = DecisionTreeClassifier (criterion = 'gini', max_depth = 14)

dt.fit(X_train,y_train)
y_pred = dt.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
accuracy_score(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#   functional       0.79      0.86      0.82      6603
# needs repair       0.79      0.69      0.74      5002
#
#     accuracy                           0.79     11605
#    macro avg       0.79      0.77      0.78     11605
# weighted avg       0.79      0.79      0.78     11605
# 0.7859543300301595

# %%
from sklearn import linear_model
from sklearn.metrics import roc_auc_score

X = X_train
y = y_train
logreg = linear_model.LogisticRegression()
logreg.fit(X, y)
predictions = logreg.predict_proba(X)[:,1]
auc = roc_auc_score(y, predictions)
print(auc)
# Out:
# 0.8171447151492137
# C:\Users\Asaph Tinoco\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=8)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred))
accuracy_score(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#   functional       0.70      0.84      0.77      6603
# needs repair       0.72      0.53      0.61      5002
#
#     accuracy                           0.71     11605
#    macro avg       0.71      0.69      0.69     11605
# weighted avg       0.71      0.71      0.70     11605
# 0.7090909090909091

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestClassifier
# Instantiate model with 1000 decision trees
rf = RandomForestClassifier(n_estimators = 1000)
# Train the model on training data
rf.fit(X_train, y_train)
print(classification_report(y_test, y_pred))
accuracy_score(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#   functional       0.70      0.84      0.77      6603
# needs repair       0.72      0.53      0.61      5002
#
#     accuracy                           0.71     11605
#    macro avg       0.71      0.69      0.69     11605
# weighted avg       0.71      0.71      0.70     11605
# 0.7090909090909091

# %%
import xgboost as xgb
classifier = xgb.XGBClassifier()
# test_df = X_train.loc[:,~X_train.columns.duplicated()]
# test_df.info()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred))
accuracy_score(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#   functional       0.76      0.88      0.81      6603
# needs repair       0.80      0.63      0.71      5002
#
#     accuracy                           0.77     11605
#    macro avg       0.78      0.75      0.76     11605
# weighted avg       0.77      0.77      0.77     11605
# 0.7716501507970702
